# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of random latitude and longitude combinations to the size of 2000.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wdesc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wdesc})
#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | turbat
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | khandyga
# Processing Record 5 of Set 1 | pinawa
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | seoul
# Processing Record 8 of Set 1 | lhokseumawe
# Processing Record 9 of Set 1 | honningsvag
# Processing Record 10 of Set 1 | isangel
# Processing Record 11 of Set 1 | coihaique
# Processing Record 12 of Set 1 | darhan
# Processing Record 13 of Set 1 | hovd
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | camacha
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | dakoro
# Processing Record 22 of Set 1 | rocha
# Processing Record 23 of Set 1 | saint-georges
# Processing Record 24 of Set 1 | biak
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | tombouctou
# Processing Record 27 of Set 1 | bati
# Processing Record 28 of Set 1 | asau
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | nanortalik
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | te anau
# Processing Record 34 of Set 1 | sisimiut
# Processing Record 35 of Set 1 | san jose
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | yiyang
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | atherton
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | chimbote
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | hurghada
# Processing Record 49 of Set 1 | muisne
# Processing Record 50 of Set 1 | amapa
# Processing Record 1 of Set 2 | katangli
# Processing Record 2 of Set 2 | buin
# Processing Record 3 of Set 2 | noumea
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | kenai
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | lorengau
# Processing Record 11 of Set 2 | nome
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | joao pinheiro
# Processing Record 14 of Set 2 | santa isabel do rio negro
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | walvis bay
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | pascagoula
# Processing Record 20 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 21 of Set 2 | fershampenuaz
# Processing Record 22 of Set 2 | kieta
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | kirakira
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | half moon bay
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | kysyl-syr
# Processing Record 36 of Set 2 | bilibino
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | molochnyy
# Processing Record 40 of Set 2 | norman wells
# Processing Record 41 of Set 2 | katsuura
# Processing Record 42 of Set 2 | necochea
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | manacapuru
# Processing Record 45 of Set 2 | vestmanna
# Processing Record 46 of Set 2 | verkh-chebula
# Processing Record 47 of Set 2 | dingle
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | vao
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | mattru
# Processing Record 2 of Set 3 | kamenka
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | lagoa
# Processing Record 6 of Set 3 | korla
# Processing Record 7 of Set 3 | churapcha
# Processing Record 8 of Set 3 | lata
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | dhidhdhoo
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | san lorenzo
# Processing Record 16 of Set 3 | north bend
# Processing Record 17 of Set 3 | boa vista
# Processing Record 18 of Set 3 | salym
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | hami
# Processing Record 22 of Set 3 | qinhuangdao
# Processing Record 23 of Set 3 | abu dhabi
# Processing Record 24 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 3 | brandon
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | daru
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 3 | florencia
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | araouane
# Processing Record 34 of Set 3 | srandakan
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | gejiu
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | ponta delgada
# Processing Record 41 of Set 3 | avon park
# Processing Record 42 of Set 3 | manga
# Processing Record 43 of Set 3 | lasa
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | alofi
# Processing Record 46 of Set 3 | kashi
# Processing Record 47 of Set 3 | emba
# Processing Record 48 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 3 | waingapu
# Processing Record 50 of Set 3 | zitlala
# Processing Record 1 of Set 4 | bayir
# Processing Record 2 of Set 4 | marzuq
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | porto santo
# Processing Record 5 of Set 4 | kropotkin
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | tignere
# Processing Record 9 of Set 4 | russell
# Processing Record 10 of Set 4 | sinjai
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | verkhnetulomskiy
# Processing Record 13 of Set 4 | wanning
# Processing Record 14 of Set 4 | orel-izumrud
# Processing Record 15 of Set 4 | camana
# Processing Record 16 of Set 4 | bumba
# Processing Record 17 of Set 4 | bluff
# Processing Record 18 of Set 4 | alta floresta
# Processing Record 19 of Set 4 | burdur
# Processing Record 20 of Set 4 | pacific grove
# Processing Record 21 of Set 4 | ginda
# Processing Record 22 of Set 4 | shache
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | nueva gerona
# Processing Record 25 of Set 4 | tiznit
# Processing Record 26 of Set 4 | szob
# Processing Record 27 of Set 4 | constantine
# Processing Record 28 of Set 4 | atasu
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | majenang
# Processing Record 31 of Set 4 | bairiki
# Processing Record 32 of Set 4 | orapa
# Processing Record 33 of Set 4 | ballina
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | yumen
# Processing Record 37 of Set 4 | saint-philippe
# Processing Record 38 of Set 4 | navalmoral de la mata
# Processing Record 39 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | sambava
# Processing Record 46 of Set 4 | xinzhou
# Processing Record 47 of Set 4 | ucluelet
# Processing Record 48 of Set 4 | langarud
# Processing Record 49 of Set 4 | mount pleasant
# Processing Record 50 of Set 4 | marawi
# Processing Record 1 of Set 5 | thunder bay
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | san-pedro
# Processing Record 4 of Set 5 | opuwo
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | khakhea
# Processing Record 7 of Set 5 | toora-khem
# Processing Record 8 of Set 5 | lekoni
# Processing Record 9 of Set 5 | tshane
# Processing Record 10 of Set 5 | rio grande
# Processing Record 11 of Set 5 | sakhipur
# Processing Record 12 of Set 5 | kochubey
# Processing Record 13 of Set 5 | selizharovo
# Processing Record 14 of Set 5 | byron bay
# Processing Record 15 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 5 | hambantota
# Processing Record 18 of Set 5 | birjand
# Processing Record 19 of Set 5 | wajima
# Processing Record 20 of Set 5 | ahipara
# Processing Record 21 of Set 5 | yerbogachen
# Processing Record 22 of Set 5 | alekseyevsk
# Processing Record 23 of Set 5 | turmalina
# Processing Record 24 of Set 5 | sabzevar
# Processing Record 25 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 5 | rawson
# Processing Record 27 of Set 5 | tuatapere
# Processing Record 28 of Set 5 | vredendal
# Processing Record 29 of Set 5 | constitucion
# Processing Record 30 of Set 5 | aswan
# Processing Record 31 of Set 5 | astana
# Processing Record 32 of Set 5 | lamar
# Processing Record 33 of Set 5 | komsomolskiy
# Processing Record 34 of Set 5 | westport
# Processing Record 35 of Set 5 | mayor pablo lagerenza
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | bandarbeyla
# Processing Record 38 of Set 5 | puerto escondido
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | luwuk
# Processing Record 42 of Set 5 | tevaitoa
# Processing Record 43 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 5 | along
# Processing Record 45 of Set 5 | bousso
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | hamilton
# Processing Record 48 of Set 5 | cayenne
# Processing Record 49 of Set 5 | todos santos
# Processing Record 50 of Set 5 | goderich
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | orlik
# Processing Record 3 of Set 6 | podyuga
# Processing Record 4 of Set 6 | praia da vitoria
# Processing Record 5 of Set 6 | yermakovskoye
# Processing Record 6 of Set 6 | wonthaggi
# Processing Record 7 of Set 6 | alyangula
# Processing Record 8 of Set 6 | porto novo
# Processing Record 9 of Set 6 | arona
# Processing Record 10 of Set 6 | launceston
# Processing Record 11 of Set 6 | coffeyville
# Processing Record 12 of Set 6 | malakal
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | nikki
# Processing Record 16 of Set 6 | wagga wagga
# Processing Record 17 of Set 6 | caravelas
# Processing Record 18 of Set 6 | klyuchi
# Processing Record 19 of Set 6 | pangnirtung
# Processing Record 20 of Set 6 | tete
# Processing Record 21 of Set 6 | kiama
# Processing Record 22 of Set 6 | hirado
# Processing Record 23 of Set 6 | severodvinsk
# Processing Record 24 of Set 6 | aguimes
# Processing Record 25 of Set 6 | fort frances
# Processing Record 26 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 27 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 6 | severskaya
# Processing Record 29 of Set 6 | adre
# Processing Record 30 of Set 6 | salta
# Processing Record 31 of Set 6 | saskylakh
# Processing Record 32 of Set 6 | aksu
# Processing Record 33 of Set 6 | aklavik
# Processing Record 34 of Set 6 | talara
# Processing Record 35 of Set 6 | ploemeur
# Processing Record 36 of Set 6 | coquimbo
# Processing Record 37 of Set 6 | srivardhan
# Processing Record 38 of Set 6 | nanakuli
# Processing Record 39 of Set 6 | namibe
# Processing Record 40 of Set 6 | ninghai
# Processing Record 41 of Set 6 | kununurra
# Processing Record 42 of Set 6 | mount gambier
# Processing Record 43 of Set 6 | margate
# Processing Record 44 of Set 6 | newberg
# Processing Record 45 of Set 6 | santa cruz cabralia
# Processing Record 46 of Set 6 | atar
# Processing Record 47 of Set 6 | kavaratti
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | januaria
# Processing Record 1 of Set 7 | kyle
# Processing Record 2 of Set 7 | lodja
# Processing Record 3 of Set 7 | bahia blanca
# Processing Record 4 of Set 7 | chippewa falls
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | caborca
# Processing Record 7 of Set 7 | xinyang
# Processing Record 8 of Set 7 | mitsamiouli
# Processing Record 9 of Set 7 | mgandu
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | mandalgovi
# Processing Record 12 of Set 7 | ilulissat
# Processing Record 13 of Set 7 | matehuala
# Processing Record 14 of Set 7 | labuhan
# Processing Record 15 of Set 7 | grand gaube
# Processing Record 16 of Set 7 | taga
# Processing Record 17 of Set 7 | carnarvon
# Processing Record 18 of Set 7 | senanga
# Processing Record 19 of Set 7 | beringovskiy
# Processing Record 20 of Set 7 | lunino
# Processing Record 21 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 7 | ormara
# Processing Record 23 of Set 7 | dwarka
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | zyryanka
# Processing Record 26 of Set 7 | bethel
# Processing Record 27 of Set 7 | tautira
# Processing Record 28 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 7 | katherine
# Processing Record 30 of Set 7 | suntar
# Processing Record 31 of Set 7 | bid
# City not found. Skipping...
# Processing Record 32 of Set 7 | adrar
# Processing Record 33 of Set 7 | saint-francois
# Processing Record 34 of Set 7 | santiago del estero
# Processing Record 35 of Set 7 | melito di porto salvo
# Processing Record 36 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 7 | svetlaya
# Processing Record 38 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 7 | bharatpur
# Processing Record 40 of Set 7 | port blair
# Processing Record 41 of Set 7 | tabuk
# Processing Record 42 of Set 7 | ketchikan
# Processing Record 43 of Set 7 | zhigansk
# Processing Record 44 of Set 7 | catuday
# Processing Record 45 of Set 7 | kapoeta
# Processing Record 46 of Set 7 | krasnoarmeysk
# Processing Record 47 of Set 7 | amga
# Processing Record 48 of Set 7 | tomatlan
# Processing Record 49 of Set 7 | omsukchan
# Processing Record 50 of Set 7 | hofn
# Processing Record 1 of Set 8 | maun
# Processing Record 2 of Set 8 | manohar thana
# Processing Record 3 of Set 8 | roanoke rapids
# Processing Record 4 of Set 8 | newport
# Processing Record 5 of Set 8 | palmer
# Processing Record 6 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 8 | dandong
# Processing Record 8 of Set 8 | leshukonskoye
# Processing Record 9 of Set 8 | uyemskiy
# Processing Record 10 of Set 8 | chapleau
# Processing Record 11 of Set 8 | asfi
# Processing Record 12 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 8 | lakeway
# Processing Record 14 of Set 8 | wajir
# Processing Record 15 of Set 8 | amberg
# Processing Record 16 of Set 8 | pinotepa nacional
# Processing Record 17 of Set 8 | hercegszanto
# Processing Record 18 of Set 8 | taksimo
# Processing Record 19 of Set 8 | iranshahr
# Processing Record 20 of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record 21 of Set 8 | gushi
# Processing Record 22 of Set 8 | savannah bight
# Processing Record 23 of Set 8 | areni
# Processing Record 24 of Set 8 | macia
# Processing Record 25 of Set 8 | yazoo city
# Processing Record 26 of Set 8 | qui nhon
# Processing Record 27 of Set 8 | hualmay
# Processing Record 28 of Set 8 | blyth
# Processing Record 29 of Set 8 | cap malheureux
# Processing Record 30 of Set 8 | college
# Processing Record 31 of Set 8 | maceio
# Processing Record 32 of Set 8 | amlame
# Processing Record 33 of Set 8 | cidreira
# Processing Record 34 of Set 8 | bela
# Processing Record 35 of Set 8 | ocara
# Processing Record 36 of Set 8 | creel
# Processing Record 37 of Set 8 | winslow
# Processing Record 38 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 8 | port hardy
# Processing Record 40 of Set 8 | kifri
# Processing Record 41 of Set 8 | nuuk
# Processing Record 42 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 8 | marsh harbour
# Processing Record 44 of Set 8 | finnsnes
# Processing Record 45 of Set 8 | beyneu
# Processing Record 46 of Set 8 | yangshan
# Processing Record 47 of Set 8 | tocopilla
# Processing Record 48 of Set 8 | gayeri
# Processing Record 49 of Set 8 | whitianga
# Processing Record 50 of Set 8 | ixtapa
# Processing Record 1 of Set 9 | vitim
# Processing Record 2 of Set 9 | hohhot
# Processing Record 3 of Set 9 | dunedin
# Processing Record 4 of Set 9 | tanshui
# City not found. Skipping...
# Processing Record 5 of Set 9 | pathein
# Processing Record 6 of Set 9 | anadyr
# Processing Record 7 of Set 9 | narsaq
# Processing Record 8 of Set 9 | saint anthony
# Processing Record 9 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 9 | chumikan
# Processing Record 11 of Set 9 | saint-joseph
# Processing Record 12 of Set 9 | kandrian
# Processing Record 13 of Set 9 | marienburg
# Processing Record 14 of Set 9 | axim
# Processing Record 15 of Set 9 | geraldton
# Processing Record 16 of Set 9 | champerico
# Processing Record 17 of Set 9 | trinidad
# Processing Record 18 of Set 9 | avera
# Processing Record 19 of Set 9 | genhe
# Processing Record 20 of Set 9 | les cayes
# Processing Record 21 of Set 9 | moron
# Processing Record 22 of Set 9 | general roca
# Processing Record 23 of Set 9 | guerrero negro
# Processing Record 24 of Set 9 | taltal
# Processing Record 25 of Set 9 | aksarka
# Processing Record 26 of Set 9 | quesnel
# Processing Record 27 of Set 9 | suao
# City not found. Skipping...
# Processing Record 28 of Set 9 | moscow
# Processing Record 29 of Set 9 | majene
# Processing Record 30 of Set 9 | kargasok
# Processing Record 31 of Set 9 | khatanga
# Processing Record 32 of Set 9 | masaurhi
# Processing Record 33 of Set 9 | chokwe
# Processing Record 34 of Set 9 | disna
# Processing Record 35 of Set 9 | valparaiso
# Processing Record 36 of Set 9 | tacna
# Processing Record 37 of Set 9 | juneau
# Processing Record 38 of Set 9 | palu
# Processing Record 39 of Set 9 | bathsheba
# Processing Record 40 of Set 9 | pimentel
# Processing Record 41 of Set 9 | ritchie
# Processing Record 42 of Set 9 | diamantino
# Processing Record 43 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 9 | oranjemund
# Processing Record 45 of Set 9 | manitouwadge
# Processing Record 46 of Set 9 | sabha
# Processing Record 47 of Set 9 | barcelos
# Processing Record 48 of Set 9 | saldanha
# Processing Record 49 of Set 9 | mongomo
# Processing Record 50 of Set 9 | prince rupert
# Processing Record 1 of Set 10 | angoche
# Processing Record 2 of Set 10 | perth
# Processing Record 3 of Set 10 | vanavara
# Processing Record 4 of Set 10 | sorong
# Processing Record 5 of Set 10 | saint-augustin
# Processing Record 6 of Set 10 | marechal deodoro
# Processing Record 7 of Set 10 | hervey bay
# Processing Record 8 of Set 10 | ostrovnoy
# Processing Record 9 of Set 10 | jhabua
# Processing Record 10 of Set 10 | maracacume
# Processing Record 11 of Set 10 | ures
# Processing Record 12 of Set 10 | garissa
# Processing Record 13 of Set 10 | tucuma
# Processing Record 14 of Set 10 | qaqortoq
# Processing Record 15 of Set 10 | lokken verk
# City not found. Skipping...
# Processing Record 16 of Set 10 | merauke
# Processing Record 17 of Set 10 | gayny
# Processing Record 18 of Set 10 | makakilo city
# Processing Record 19 of Set 10 | hefei
# Processing Record 20 of Set 10 | chenghai
# Processing Record 21 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 10 | meadow lake
# Processing Record 23 of Set 10 | ulaangom
# Processing Record 24 of Set 10 | libertador general san martin
# Processing Record 25 of Set 10 | high level
# Processing Record 26 of Set 10 | jacareacanga
# Processing Record 27 of Set 10 | afanasyevo
# City not found. Skipping...
# Processing Record 28 of Set 10 | gualaca
# Processing Record 29 of Set 10 | conakry
# Processing Record 30 of Set 10 | coruripe
# Processing Record 31 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 10 | paamiut
# Processing Record 33 of Set 10 | sinnamary
# Processing Record 34 of Set 10 | salinas
# Processing Record 35 of Set 10 | kasane
# Processing Record 36 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 10 | sayat
# Processing Record 38 of Set 10 | unguia
# Processing Record 39 of Set 10 | pteleos
# Processing Record 40 of Set 10 | nelson bay
# Processing Record 41 of Set 10 | chivay
# Processing Record 42 of Set 10 | diego de almagro
# Processing Record 43 of Set 10 | hirara
# Processing Record 44 of Set 10 | pavlovsk
# Processing Record 45 of Set 10 | dodge city
# Processing Record 46 of Set 10 | vanersborg
# Processing Record 47 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 10 | emilio carranza
# Processing Record 49 of Set 10 | chaihe
# Processing Record 50 of Set 10 | ponta do sol
# Processing Record 1 of Set 11 | dicabisagan
# Processing Record 2 of Set 11 | luwingu
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | porto nacional
# Processing Record 5 of Set 11 | koumac
# Processing Record 6 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 11 | yar-sale
# Processing Record 8 of Set 11 | mastic beach
# Processing Record 9 of Set 11 | malente
# Processing Record 10 of Set 11 | sao filipe
# Processing Record 11 of Set 11 | miri
# Processing Record 12 of Set 11 | sioux lookout
# Processing Record 13 of Set 11 | esmeraldas
# Processing Record 14 of Set 11 | leningradskiy
# Processing Record 15 of Set 11 | voskresenskoye
# Processing Record 16 of Set 11 | dudinka
# Processing Record 17 of Set 11 | lampazos de naranjo
# Processing Record 18 of Set 11 | skjervoy
# Processing Record 19 of Set 11 | akdepe
# Processing Record 20 of Set 11 | george
# Processing Record 21 of Set 11 | wang noi
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | chiang klang
# Processing Record 24 of Set 11 | wenling
# Processing Record 25 of Set 11 | vestmannaeyjar
# Processing Record 26 of Set 11 | kazanskoye
# Processing Record 27 of Set 11 | turkistan
# Processing Record 28 of Set 11 | mayo
# Processing Record 29 of Set 11 | paita
# Processing Record 30 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 11 | camacari
# Processing Record 32 of Set 11 | borisoglebskiy
# Processing Record 33 of Set 11 | pestravka
# Processing Record 34 of Set 11 | iquique
# Processing Record 35 of Set 11 | muswellbrook
# Processing Record 36 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 11 | padang
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | trincomalee
# Processing Record 40 of Set 11 | cranbourne
# Processing Record 41 of Set 11 | labytnangi
# Processing Record 42 of Set 11 | madison heights
# Processing Record 43 of Set 11 | cancun
# Processing Record 44 of Set 11 | salalah
# Processing Record 45 of Set 11 | salinopolis
# Processing Record 46 of Set 11 | garmsar
# Processing Record 47 of Set 11 | cherskiy
# Processing Record 48 of Set 11 | roma
# Processing Record 49 of Set 11 | namuac
# Processing Record 50 of Set 11 | harnosand
# Processing Record 1 of Set 12 | changji
# Processing Record 2 of Set 12 | verkhniy mamon
# Processing Record 3 of Set 12 | hithadhoo
# Processing Record 4 of Set 12 | krasnoye-na-volge
# Processing Record 5 of Set 12 | wahiawa
# Processing Record 6 of Set 12 | sorland
# Processing Record 7 of Set 12 | lavrentiya
# Processing Record 8 of Set 12 | takoradi
# Processing Record 9 of Set 12 | gao
# Processing Record 10 of Set 12 | atambua
# Processing Record 11 of Set 12 | druzhba
# Processing Record 12 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 13 of Set 12 | manokwari
# Processing Record 14 of Set 12 | gorom-gorom
# Processing Record 15 of Set 12 | sistranda
# Processing Record 16 of Set 12 | pochutla
# Processing Record 17 of Set 12 | san antonio
# Processing Record 18 of Set 12 | boende
# Processing Record 19 of Set 12 | banjar
# Processing Record 20 of Set 12 | sloboda
# Processing Record 21 of Set 12 | xining
# Processing Record 22 of Set 12 | taoudenni
# Processing Record 23 of Set 12 | nyurba
# Processing Record 24 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 12 | belmonte
# Processing Record 27 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 12 | muros
# Processing Record 29 of Set 12 | abomey-calavi
# Processing Record 30 of Set 12 | eureka
# Processing Record 31 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 32 of Set 12 | crotone
# Processing Record 33 of Set 12 | cururupu
# Processing Record 34 of Set 12 | kibakwe
# Processing Record 35 of Set 12 | aljezur
# Processing Record 36 of Set 12 | tonj
# Processing Record 37 of Set 12 | yanam
# Processing Record 38 of Set 12 | tessalit
# Processing Record 39 of Set 12 | kosa
# Processing Record 40 of Set 12 | punta gorda
# Processing Record 41 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 12 | labuan
# Processing Record 43 of Set 12 | hasaki
# Processing Record 44 of Set 12 | buala
# Processing Record 45 of Set 12 | gravdal
# Processing Record 46 of Set 12 | khani
# Processing Record 47 of Set 12 | los llanos de aridane
# Processing Record 48 of Set 12 | virginia beach
# Processing Record 49 of Set 12 | mokhsogollokh
# Processing Record 50 of Set 12 | bubaque
# Processing Record 1 of Set 13 | sicamous
# Processing Record 2 of Set 13 | yuanping
# Processing Record 3 of Set 13 | leh
# Processing Record 4 of Set 13 | vanimo
# Processing Record 5 of Set 13 | la union
# Processing Record 6 of Set 13 | gracac
# Processing Record 7 of Set 13 | paragominas
# Processing Record 8 of Set 13 | fort nelson
# Processing Record 9 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 13 | fushun
# Processing Record 11 of Set 13 | manta
# Processing Record 12 of Set 13 | ampanihy
# Processing Record 13 of Set 13 | belaya gora
# Processing Record 14 of Set 13 | ribeira brava
# Processing Record 15 of Set 13 | stanger
# Processing Record 16 of Set 13 | inhambane
# Processing Record 17 of Set 13 | bavly
# Processing Record 18 of Set 13 | temerin
# Processing Record 19 of Set 13 | mitu
# Processing Record 20 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 13 | chapais
# Processing Record 22 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 13 | shimoda
# Processing Record 24 of Set 13 | adzhamka
# Processing Record 25 of Set 13 | almeirim
# Processing Record 26 of Set 13 | fairbanks
# Processing Record 27 of Set 13 | deputatskiy
# Processing Record 28 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 13 | ambon
# Processing Record 30 of Set 13 | yamada
# Processing Record 31 of Set 13 | ercis
# Processing Record 32 of Set 13 | san juan
# Processing Record 33 of Set 13 | black river
# Processing Record 34 of Set 13 | tagab
# Processing Record 35 of Set 13 | brae
# Processing Record 36 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 37 of Set 13 | calvinia
# Processing Record 38 of Set 13 | longonjo
# Processing Record 39 of Set 13 | larsnes
# Processing Record 40 of Set 13 | vardo
# Processing Record 41 of Set 13 | lompoc
# Processing Record 42 of Set 13 | mtwara
# Processing Record 43 of Set 13 | ledyard
# Processing Record 44 of Set 13 | gigmoto
# Processing Record 45 of Set 13 | kousseri
# Processing Record 46 of Set 13 | eurajoki
# Processing Record 47 of Set 13 | ugep
# Processing Record 48 of Set 13 | kabare
# Processing Record 49 of Set 13 | san carlos de bariloche
# Processing Record 50 of Set 13 | mayumba
# Processing Record 1 of Set 14 | tutoia
# Processing Record 2 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 14 | vostok
# Processing Record 4 of Set 14 | ambulu
# Processing Record 5 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 14 | maues
# Processing Record 7 of Set 14 | alegrete
# Processing Record 8 of Set 14 | burnie
# Processing Record 9 of Set 14 | pangody
# Processing Record 10 of Set 14 | mbalmayo
# Processing Record 11 of Set 14 | orillia
# Processing Record 12 of Set 14 | ust-uda
# Processing Record 13 of Set 14 | gordeyevka
# Processing Record 14 of Set 14 | wagar
# Processing Record 15 of Set 14 | matamoros
# Processing Record 16 of Set 14 | henties bay
# Processing Record 17 of Set 14 | micheweni
# Processing Record 18 of Set 14 | pitimbu
# Processing Record 19 of Set 14 | quelimane
# Processing Record 20 of Set 14 | moen
# Processing Record 21 of Set 14 | kutum
# Processing Record 22 of Set 14 | yeppoon
# Processing Record 23 of Set 14 | gizo
# Processing Record 24 of Set 14 | mwinilunga
# Processing Record 25 of Set 14 | witrivier
# City not found. Skipping...
# Processing Record 26 of Set 14 | vizinga
# Processing Record 27 of Set 14 | porto-vecchio
# Processing Record 28 of Set 14 | tambul
# City not found. Skipping...
# Processing Record 29 of Set 14 | omboue
# Processing Record 30 of Set 14 | wad madani
# Processing Record 31 of Set 14 | krasnokamensk
# Processing Record 32 of Set 14 | nova vicosa
# Processing Record 33 of Set 14 | najran
# Processing Record 34 of Set 14 | turukhansk
# Processing Record 35 of Set 14 | kudahuvadhoo
# Processing Record 36 of Set 14 | aquiraz
# Processing Record 37 of Set 14 | beawar
# Processing Record 38 of Set 14 | ruteng
# Processing Record 39 of Set 14 | luba
# Processing Record 40 of Set 14 | keffi
# Processing Record 41 of Set 14 | chapayevka
# Processing Record 42 of Set 14 | elizabeth city
# Processing Record 43 of Set 14 | witu
# Processing Record 44 of Set 14 | kloulklubed
# Processing Record 45 of Set 14 | teguise
# Processing Record 46 of Set 14 | talavera de la reina
# Processing Record 47 of Set 14 | englewood
# Processing Record 48 of Set 14 | san isidro
# Processing Record 49 of Set 14 | perry
# Processing Record 50 of Set 14 | payo
# Processing Record 1 of Set 15 | palauig
# Processing Record 2 of Set 15 | kiunga
# Processing Record 3 of Set 15 | comodoro rivadavia
# Processing Record 4 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 15 | belyy yar
# Processing Record 6 of Set 15 | carepa
# Processing Record 7 of Set 15 | barra dos coqueiros
# Processing Record 8 of Set 15 | ndjole
# Processing Record 9 of Set 15 | asosa
# Processing Record 10 of Set 15 | lac du bonnet
# Processing Record 11 of Set 15 | pringsewu
# Processing Record 12 of Set 15 | khotyn
# Processing Record 13 of Set 15 | severnyy
# Processing Record 14 of Set 15 | pihuamo
# Processing Record 15 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 15 | bambanglipuro
# Processing Record 17 of Set 15 | maningrida
# Processing Record 18 of Set 15 | yatou
# Processing Record 19 of Set 15 | itanhem
# Processing Record 20 of Set 15 | namatanai
# Processing Record 21 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 22 of Set 15 | oktyabrskiy
# Processing Record 23 of Set 15 | san vicente
# Processing Record 24 of Set 15 | kuito
# Processing Record 25 of Set 15 | abengourou
# Processing Record 26 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 15 | tual
# Processing Record 28 of Set 15 | qena
# Processing Record 29 of Set 15 | salihorsk
# Processing Record 30 of Set 15 | sirajganj
# Processing Record 31 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 15 | corsicana
# Processing Record 33 of Set 15 | san cristobal
# Processing Record 34 of Set 15 | saryg-sep
# Processing Record 35 of Set 15 | bambous virieux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cap Malheureux      MU -19.9842   57.6142     78.48        70           5
# 1       Cape Town      ZA -33.9258   18.4232     61.27        90          75
# 2         Mataura      NZ -46.1927  168.8643     55.47        47          92
# 3     Bandarbeyla      SO   9.4942   50.8122     76.21        64           5
# 4         Salalah      OM  17.0151   54.0924     71.31        41           0
# 5   Srednekolymsk      RU  67.4500  153.6833    -48.75       100          73
# 6     New Norfolk      AU -42.7826  147.0587     64.65        50          45
# 7       Carnarvon      AU -24.8667  113.6333     77.07        69           0
# 8          Albany      US  42.6001  -73.9662     37.58        61          97
# 9        Flinders      AU -34.5833  150.8552     69.19        68          98
#
#    Wind Speed Current Description
# 0        3.00           clear sky
# 1        3.00       moderate rain
# 2        5.06     overcast clouds
# 3       16.08           clear sky
# 4        7.54           clear sky
# 5        4.61       broken clouds
# 6        1.99    scattered clouds
# 7       17.27           clear sky
# 8        4.61     overcast clouds
# 9        7.27     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
